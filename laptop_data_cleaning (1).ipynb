# %%
import pandas as pd

df = pd.read_csv("/content/cleaned_laptop_dataset.csv")

print("First 5 rows of the dataset:")
print(df.head())

print("\nDataset Information:")
print(df.info())

print("\nMissing values in each column:")
print(df.isnull().sum())

df = df.drop_duplicates()

if "Unnamed: 0" in df.columns:
  df = df.drop(columns=["Unnamed: 0"])

df.columns = df.columns.str.strip().str.lower().str.replace(" ","_")

numeric_columns = df.select_dtypes(include=["int64" ,"float64"]).columns

for col in numeric_columns:df[col] = df[col].fillna(df[col].mean())

print("\nDataset after cleaning:")
print(df.head())

df.to_csv("cleaned_laptop_dataset.csv",index=False)

print("\nData cleaning completed successfully!")
# Out:
# First 5 rows of the dataset:
#                                                 name  discounted_price  \
# 0          Apple MacBook Air 13 M1 MGN63 (8GB-256GB)          203499.0
# 1                 Apple Macbook Air 13 MW123 M4 Chip          281999.0
# 2  ASUS Zenbook 14 UX3405CA Intel Core Ultra 7 25...          285999.0
# 3  Lenovo ThinkPad E16 Gen 2 - Intel Core Ultra 7...          287999.0
# 4          Lenovo IdeaPad Slim 3 Ryzen 7 (8GB-512GB)          146999.0
#
#    actual_price   saving    rating   reviews   brand     core             ssd  \
# 0      258000.0  21% OFF  5.000000  2.000000   Apple       M1             NaN
# 1      350000.0  19% OFF  4.300000  5.000000   Apple       M4             NaN
# 2      330000.0  13% OFF  4.753846  1.615385    ASUS  Ultra 7  16GB-512GB SSD
# 3      340000.0  15% OFF  4.753846  1.615385  Lenovo  Ultra 7             NaN
# 4      175000.0  16% OFF  4.753846  1.615385  Lenovo  Ryzen 7             NaN
#
#                                          model
# 0                      MacBook Air 13 M1 MGN63
# 1                 Macbook Air 13 MW123 M4 Chip
# 2  Zenbook 14 UX3405CA Intel Core Ultra 7 255H
# 3      ThinkPad E16 Gen 2 - Intel Core Ultra 7
# 4                       IdeaPad Slim 3 Ryzen 7
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              306 non-null    object
#  1   discounted_price  306 non-null    float64
#  2   actual_price      306 non-null    float64
#  3   saving            291 non-null    object
#  4   rating            306 non-null    float64
#  5   reviews           306 non-null    float64
#  6   brand             306 non-null    object
#  7   core              219 non-null    object
#  8   ssd               92 non-null     object
#  9   model             306 non-null    object
# dtypes: float64(4), object(6)
# memory usage: 24.0+ KB
# None
#
# Missing values in each column:
# name                  0
# discounted_price      0
# actual_price          0
# saving               15
# rating                0
# reviews               0
# brand                 0
# core                 87
# ssd                 214
# model                 0
# dtype: int64
#
# Dataset after cleaning:
#                                                 name  discounted_price  \
# 0          Apple MacBook Air 13 M1 MGN63 (8GB-256GB)          203499.0
# 1                 Apple Macbook Air 13 MW123 M4 Chip          281999.0
# 2  ASUS Zenbook 14 UX3405CA Intel Core Ultra 7 25...          285999.0
# 3  Lenovo ThinkPad E16 Gen 2 - Intel Core Ultra 7...          287999.0
# 4          Lenovo IdeaPad Slim 3 Ryzen 7 (8GB-512GB)          146999.0
#
#    actual_price   saving    rating   reviews   brand     core             ssd  \
# 0      258000.0  21% OFF  5.000000  2.000000   Apple       M1             NaN
# 1      350000.0  19% OFF  4.300000  5.000000   Apple       M4             NaN
# 2      330000.0  13% OFF  4.753846  1.615385    ASUS  Ultra 7  16GB-512GB SSD
# 3      340000.0  15% OFF  4.753846  1.615385  Lenovo  Ultra 7             NaN
# 4      175000.0  16% OFF  4.753846  1.615385  Lenovo  Ryzen 7             NaN
#
#                                          model
# 0                      MacBook Air 13 M1 MGN63
# 1                 Macbook Air 13 MW123 M4 Chip
# 2  Zenbook 14 UX3405CA Intel Core Ultra 7 255H
# 3      ThinkPad E16 Gen 2 - Intel Core Ultra 7
# 4                       IdeaPad Slim 3 Ryzen 7
#
# Data cleaning completed successfully!
